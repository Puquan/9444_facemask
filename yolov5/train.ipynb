# %%
# !export COMET_API_KEY=VUzR8ty7pb0RTxOjUWDrseoM0

# %%
# !python train.py --img 512 --epochs 200 --batch 64 --data './datasets/data.yaml' --cfg 'yolov5s.yaml' --weights '' --project 'facemask_512_yolo5s' --name '512_5s_200epoch'
# Out:
# train: weights=, cfg=yolov5s.yaml, data=./datasets/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=64, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=facemask_512_yolo5s, name=512_5s_200epoch, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-10-26 Python-3.8.13 torch-1.11.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1070, 8111MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# TensorBoard: Start with 'tensorboard --logdir facemask_512_yolo5s', view at http://localhost:6006/
# COMET WARNING: Comet credentials have not been set. Comet will default to offline logging. Please set your credentials to enable online logging.
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: torch, tensorboard. Metrics and hyperparameters can still be logged using comet_ml.log_metrics() and comet_ml.log_parameters()
# COMET INFO: Using '/home/chenpuquan/Documents/project/9444_facemask/yolov5/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET ERROR: Failed to set run cmd args
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# YOLOv5s summary: 214 layers, 7025023 parameters, 7025023 gradients, 16.0 GFLOPs
#
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning '/home/chenpuquan/Documents/project/9444_facemask/yolov5/datasets/train/labels.cache' images and labels... 18756 found, 0 missing, 120 empty, 0 corrupt: 100%|██████████| 18756/18756 [00:00<?, ?it/s]
# val: Scanning '/home/chenpuquan/Documents/project/9444_facemask/yolov5/datasets/valid/labels.cache' images and labels... 3749 found, 0 missing, 10 empty, 0 corrupt: 100%|██████████| 3749/3749 [00:00<?, ?it/s]
# val: WARNING ⚠️ /home/chenpuquan/Documents/project/9444_facemask/yolov5/datasets/valid/images/test_00000027.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/chenpuquan/Documents/project/9444_facemask/yolov5/datasets/valid/images/test_00000036.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/chenpuquan/Documents/project/9444_facemask/yolov5/datasets/valid/images/test_00000498.jpg: corrupt JPEG restored and saved
#
# AutoAnchor: 5.17 anchors/target, 0.998 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to facemask_512_yolo5s/512_5s_200epoch/labels.jpg...
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to facemask_512_yolo5s/512_5s_200epoch
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/294 [00:00<?, ?it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       0/199      7.06G    0.09547    0.03543    0.02488         19        512: 100%|██████████| 294/294 [04:21<00:00,  1.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  60%|██████    | 18/30 [00:18<00:14,  1.25s/it]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 30/30 [00:34<00:00,  1.14s/it]
#                    all       3749      10753    0.00542      0.307    0.00568    0.00157
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/199      7.19G    0.07484    0.03284    0.01823         22        512: 100%|██████████| 294/294 [04:15<00:00,  1.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  63%|██████▎   | 19/30 [00:16<00:10,  1.07it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 30/30 [00:26<00:00,  1.12it/s]
#                    all       3749      10753      0.277      0.319      0.182     0.0535
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/199      7.26G    0.06099    0.02786     0.0124         13        512: 100%|██████████| 294/294 [04:13<00:00,  1.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  60%|██████    | 18/30 [00:16<00:11,  1.09it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 30/30 [00:27<00:00,  1.08it/s]
#                    all       3749      10753       0.45      0.425      0.328      0.107
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/199      7.26G    0.05301     0.0251   0.009682         10        512: 100%|██████████| 294/294 [04:12<00:00,  1.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  63%|██████▎   | 19/30 [00:17<00:11,  1.02s/it]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 30/30 [00
/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 30/30 [00:24<00:00,  1.21it/s]
#                    all       3749      10753      0.895      0.839      0.878      0.474
#
# 200 epochs completed in 15.592 hours.
# Optimizer stripped from facemask_512_yolo5s/512_5s_200epoch/weights/last.pt, 14.3MB
# Optimizer stripped from facemask_512_yolo5s/512_5s_200epoch/weights/best.pt, 14.3MB
#
# Validating facemask_512_yolo5s/512_5s_200epoch/weights/best.pt...
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  60%|██████    | 18/30 [00:22<00:12,  1.08s/it]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 30/30 [00:33<00:00,  1.13s/it]
#                    all       3749      10753      0.891      0.843      0.879      0.474
#                   mask       3749       8112      0.931       0.89      0.924      0.524
#                   face       3749       2641      0.851      0.795      0.834      0.424
# Results saved to facemask_512_yolo5s/512_5s_200epoch
# COMET INFO: ----------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ----------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     metrics/mAP_0.5 [200]      : (0.0056817773690554345, 0.8807880396641397)
# COMET INFO:     metrics/mAP_0.5:0.95 [200] : (0.0015704908314238238, 0.4743694461499774)
# COMET INFO:     metrics/precision [200]    : (0.0054217118938749516, 0.8963282173792533)
# COMET INFO:     metrics/recall [200]       : (0.30741016809722577, 0.846340732318084)
# COMET INFO:     train/box_loss [200]       : (0.02674887329339981, 0.09547112137079239)
# COMET INFO:     train/cls_loss [200]       : (0.0009401852730661631, 0.024883830919861794)
# COMET INFO:     train/obj_loss [200]       : (0.014453780837357044, 0.03542785346508026)
# COMET INFO:     val/box_loss [200]         : (0.03222143277525902, 0.08340425044298172)
# COMET INFO:     val/cls_loss [200]         : (0.005363828036934137, 0.033953048288822174)
# COMET INFO:     val/obj_loss [200]         : (0.016976436600089073, 0.03656556084752083)
# COMET INFO:     x/lr0 [200]                : (0.0001990000000000001, 0.07010204081632654)
# COMET INFO:     x/lr1 [200]                : (0.0001990000000000001, 0.009889774376417233)
# COMET INFO:     x/lr2 [200]                : (0.0001990000000000001, 0.009889774376417233)
# COMET INFO:   Others:
# COMET INFO:     Created from                : YOLOv5
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     offline_experiment          : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t           : 4.0
# COMET INFO:     artifact_alias     : latest
# COMET INFO:     batch_size         : 64
# COMET INFO:     bbox_interval      : -1
# COMET INFO:     box                : 0.05
# COMET INFO:     bucket             :
# COMET INFO:     cache              : 1
# COMET INFO:     cfg                : /home/chenpuquan/Documents/project/9444_facemask/yolov5/models/yolov5s.yaml
# COMET INFO:     cls                : 0.012500000000000002
# COMET INFO:     cls_pw             : 1.0
# COMET INFO:     copy_paste         : 0.0
# COMET INFO:     cos_lr             : False
# COMET INFO:     data               : ./datasets/data.yaml
# COMET INFO:     degrees            : 0.0
# COMET INFO:     device             :
# COMET INFO:     entity             : 1
# COMET INFO:     epochs             : 200
# COMET INFO:     evolve             : 1
# COMET INFO:     exist_ok           : False
# COMET INFO:     fl_gamma           : 0.0
# COMET INFO:     fliplr             : 0.5
# COMET INFO:     flipud             : 0.0
# COMET INFO:     freeze             : [0]
# COMET INFO:     hsv_h              : 0.015
# COMET INFO:     hsv_s              : 0.7
# COMET INFO:     hsv_v              : 0.4
# COMET INFO:     hyp                : {"anchor_t": 4.0, "box": 0.05, "cls": 0.5, "cls_pw": 1.0, "copy_paste": 0.0, "degrees": 0.0, "fl_gamma": 0.0, "fliplr": 0.5, "flipud": 0.0, "hsv_h": 0.015, "hsv_s": 0.7, "hsv_v": 0.4, "iou_t": 0.2, "lr0": 0.01, "lrf": 0.01, "mixup": 0.0, "momentum": 0.937, "mosaic": 1.0, "obj": 1.0, "obj_pw": 1.0, "perspective": 0.0, "scale": 0.5, "shear": 0.0, "translate": 0.1, "warmup_bias_lr": 0.1, "warmup_epochs": 3.0, "warmup_momentum": 0.8, "weight_decay": 0.0005}
# COMET INFO:     image_weights      : False
# COMET INFO:     imgsz              : 512
# COMET INFO:     iou_t              : 0.2
# COMET INFO:     label_smoothing    : 0.0
# COMET INFO:     local_rank         : -1
# COMET INFO:     lr0                : 0.01
# COMET INFO:     lrf                : 0.01
# COMET INFO:     mixup              : 0.0
# COMET INFO:     momentum           : 0.937
# COMET INFO:     mosaic             : 1.0
# COMET INFO:     multi_scale        : False
# COMET INFO:     name               : 512_5s_200epoch
# COMET INFO:     noautoanchor       : False
# COMET INFO:     noplots            : False
# COMET INFO:     nosave             : False
# COMET INFO:     noval              : False
# COMET INFO:     obj                : 0.6400000000000001
# COMET INFO:     obj_pw             : 1.0
# COMET INFO:     optimizer          : SGD
# COMET INFO:     patience           : 100
# COMET INFO:     perspective        : 0.0
# COMET INFO:     project            : facemask_512_yolo5s
# COMET INFO:     quad               : False
# COMET INFO:     rect               : False
# COMET INFO:     resume             : False
# COMET INFO:     save_dir           : facemask_512_yolo5s/512_5s_200epoch
# COMET INFO:     save_period        : -1
# COMET INFO:     scale              : 0.5
# COMET INFO:     seed               : 0
# COMET INFO:     shear              : 0.0
# COMET INFO:     single_cls         : False
# COMET INFO:     sync_bn            : False
# COMET INFO:     translate          : 0.1
# COMET INFO:     upload_dataset     : False
# COMET INFO:     val_conf_threshold : 0.001
# COMET INFO:     val_iou_threshold  : 0.6
# COMET INFO:     warmup_bias_lr     : 0.1
# COMET INFO:     warmup_epochs      : 3.0
# COMET INFO:     warmup_momentum    : 0.8
# COMET INFO:     weight_decay       : 0.0005
# COMET INFO:     weights            :
# COMET INFO:     workers            : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 13 (1.29 MB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     confusion-matrix             : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     images                       : 76
# COMET INFO:     installed packages           : 1
# COMET INFO:     os packages                  : 1
# COMET INFO: ----------------------------------
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: torch, tensorboard. Metrics and hyperparameters can still be logged using comet_ml.log_metrics() and comet_ml.log_parameters()
# COMET INFO: Still saving offline stats to messages file before program termination (may take up to 120 seconds)
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/chenpuquan/Documents/project/9444_facemask/yolov5/.cometml-runs/1d5dc3babed24718bd6e762badaed911.zip
